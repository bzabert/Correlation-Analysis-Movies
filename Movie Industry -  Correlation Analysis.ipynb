# %% [markdown]
# ### Import libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize']=(12,8)

# %% [markdown]
# ### Importing data

# %%
# Read the csv file
df =pd.read_csv('/Users/bzabert/Documents/Portfolio/Python/Correlation Analysis/movies.csv')
df
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
# ...

# %% [markdown]
# ### Data Exploration and Cleaning

# %%
# Explore data
df.describe()
# Out:
#               year        score         votes        budget         gross  \
# count  7668.000000  7665.000000  7.665000e+03  5.497000e+03  7.479000e+03
# mean   2000.405451     6.390411  8.810850e+04  3.558988e+07  7.850054e+07
# std      11.153508     0.968842  1.633238e+05  4.145730e+07  1.657251e+08
# min    1980.000000     1.900000  7.000000e+00  3.000000e+03  3.090000e+02
# 25%    1991.000000     5.800000  9.100000e+03  1.000000e+07  4.532056e+06
# 50%    2000.000000     6.500000  3.300000e+04  2.050000e+07  2.020576e+07
# 75%    2010.000000     7.100000  9.300000e+04  4.500000e+07  7.601669e+07
# max    2020.000000     9.300000  2.400000e+06  3.560000e+08  2.847246e+09
#
#            runtime
# count  7664.000000
# mean    107.261613
# std      18.581247
# min      55.000000
# 25%      95.000000
# 50%     104.000000
# 75%     116.000000
# max     366.000000

# %%
# Looking for missing values in each columns

for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, pct_missing))
# Out:
# name - 0.0%
# rating - 0.010041731872717789%
# genre - 0.0%
# year - 0.0%
# released - 0.0002608242044861763%
# score - 0.0003912363067292645%
# votes - 0.0003912363067292645%
# director - 0.0%
# writer - 0.0003912363067292645%
# star - 0.00013041210224308815%
# country - 0.0003912363067292645%
# budget - 0.2831246739697444%
# gross - 0.02464788732394366%
# company - 0.002217005738132499%
# runtime - 0.0005216484089723526%

# %%
df.dropna(inplace= True)
df
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7648                               Bad Boys for Life          R     Action
# 7649                              Sonic the Hedgehog         PG     Action
# 7650                                        Dolittle         PG  Adventure
# 7651                            The Call of the Wild         PG  Adventure
# 7652                               The Eight Hundred  Not Rated     Action
#
#       year                           released  score      votes  \
# ...

# %%
# Looking at the Data types
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
# Modifing the data types
df['votes'] = df['votes'].astype('int64')
df['budget'] = df['budget'].astype('int64')
df['gross'] = df['gross'].astype('int64')
df
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7648                               Bad Boys for Life          R     Action
# 7649                              Sonic the Hedgehog         PG     Action
# 7650                                        Dolittle         PG  Adventure
# 7651                            The Call of the Wild         PG  Adventure
# 7652                               The Eight Hundred  Not Rated     Action
#
#       year                           released  score    votes  \
# ...

# %%
# Diving the year of realeased and the country
df[['released_date', 'country_released']] = df['released'].str.split('(', expand= True)
df.loc[df['released_date'].str.contains("1982", case=False)]
# Out:
#                           name rating      genre  year  \
# 97                     Porky's      R     Comedy  1981
# 101                  Mad Max 2      R     Action  1981
# 118           Chariots of Fire     PG  Biography  1981
# 129               Cutter's Way      R      Crime  1981
# 130             Quest for Fire      R  Adventure  1981
# ..                         ...    ...        ...   ...
# 305  Things Are Tough All Over      R     Action  1982
# 307                    Jinxed!      R     Comedy  1982
# 312       Five Days One Summer     PG      Drama  1982
# 315                   Partners      R     Comedy  1982
# 319               Yes, Giorgio     PG     Comedy  1982
#
#                                released  score   votes               director  \
# 97       March 19, 1982 (United States)    6.2   40000              Bob Clark
# 101        May 21, 1982 (United States)    7.6  170000          George Miller
# ...

# %%
# If the date of release has only the year we will set it for the  01 of January
df.at[312,'released_date']='January 1, 1982'
df.at[800,'released_date']='January 1, 1985'
df.at[1173,'released_date']='January 1, 1987'
df.at[1177,'released_date']='January 1, 1987'
df.at[2816,'released_date']='January 1, 1995'
df.at[4187,'released_date']='January 1, 2019'

# %%
# Formating the columns
months = {'January':'01' , 'February' : '02', 'March':'03' , 'April' : '04','May':'05' , 'June' : '06', 'July':'07' , 'August' : '08', 'September':'09' , 'October' : '10','November':'11' , 'December' : '12'}

def format_date(row):
    row_list = row.split(' ')
    result = row_list[1][:-1]+ '-'+months[row_list[0]]+'-'+row_list[2]
    return result

df['country_released'] =df['country_released'].str[:-1]
df['released_date'] = df['released_date'].apply(lambda x: format_date(x))
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score    votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %%
# Sorting by gross revenue
df.sort_values(by= 'gross',inplace= False,ascending=False).head()
# Out:
#                                             name rating   genre  year  \
# 5445                                      Avatar  PG-13  Action  2009
# 7445                           Avengers: Endgame  PG-13  Action  2019
# 3045                                     Titanic  PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action  2015
# 7244                      Avengers: Infinity War  PG-13  Action  2018
#
#                                released  score    votes       director  \
# 5445  December 18, 2009 (United States)    7.8  1100000  James Cameron
# 7445     April 26, 2019 (United States)    8.4   903000  Anthony Russo
# 3045  December 19, 1997 (United States)    7.8  1100000  James Cameron
# 6663  December 18, 2015 (United States)    7.8   876000    J.J. Abrams
# 7244     April 27, 2018 (United States)    8.4   897000  Anthony Russo
#
#                   writer               star        country     budget  \
# ...

# %%
# Droping duplicates
#pd.set_option('display.max_rows',None)
df['company'].drop_duplicates().sort_values(ascending=False)
# Out:
# 7129                                thefyzz
# 5664                            micro_scope
# 4007                               i5 Films
# 6793                             i am OTHER
# 6420                                   erbp
#                        ...
# 385                        1818 Productions
# 2929                          1492 Pictures
# 3024                        .406 Production
# 7525    "Weathering With You" Film Partners
# 4345        "DIA" Productions GmbH & Co. KG
# Name: company, Length: 1475, dtype: object

# %% [markdown]
# ### Correlation Analysis

# %%
plt.scatter(x= df['budget'], y= df['gross'] )
plt.title('Budget vs Gross Earnings')
plt.xlabel('Gross Earnings ($)')
plt.ylabel('Budget ($)')
plt.show()

# %%
# Plot budget vs Earning in seaborn

sns.regplot(x='budget',y='gross', data=df, scatter_kws = {'color':'red'}, line_kws= {'color':'blue'})
# Out:
# <AxesSubplot:xlabel='budget', ylabel='gross'>

# %%
#Pearson Correlation 
df.corr(method= 'pearson')
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.056386  0.206021  0.327722  0.274321  0.075077
# score    0.056386  1.000000  0.474256  0.072001  0.222556  0.414068
# votes    0.206021  0.474256  1.000000  0.439675  0.614751  0.352303
# budget   0.327722  0.072001  0.439675  1.000000  0.740247  0.318695
# gross    0.274321  0.222556  0.614751  0.740247  1.000000  0.275796
# runtime  0.075077  0.414068  0.352303  0.318695  0.275796  1.000000

# %%
#Kendall Correlation 
df.corr(method= 'kendall')
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.039389  0.296512  0.220833  0.239539  0.064824
# score    0.039389  1.000000  0.350185 -0.006406  0.124943  0.292254
# votes    0.296512  0.350185  1.000000  0.346274  0.553625  0.205344
# budget   0.220833 -0.006406  0.346274  1.000000  0.512057  0.231278
# gross    0.239539  0.124943  0.553625  0.512057  1.000000  0.176979
# runtime  0.064824  0.292254  0.205344  0.231278  0.176979  1.000000

# %%
#Spearman Correlarion
df.corr(method= 'spearman')
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.057741  0.427623  0.312886  0.351045  0.095444
# score    0.057741  1.000000  0.495409 -0.009971  0.183192  0.412155
# votes    0.427623  0.495409  1.000000  0.493461  0.745793  0.300621
# budget   0.312886 -0.009971  0.493461  1.000000  0.692958  0.330794
# gross    0.351045  0.183192  0.745793  0.692958  1.000000  0.257400
# runtime  0.095444  0.412155  0.300621  0.330794  0.257400  1.000000

# %%
correlation_matrix =df.corr(method= 'pearson') 

sns.heatmap(correlation_matrix, annot= True)
plt.title('Correlation Matrix')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')
# Out:
# Text(87.0, 0.5, 'Movie Features')

# %%
df_numerized = df

for col in df_numerized:
    if df_numerized[col].dtype == 'object':
        df_numerized[col] = df_numerized[col].astype('category')
        df_numerized[col] = df_numerized[col].cat.codes
        
df_numerized.head()
# Out:
#    name  rating  genre  year  released  score    votes  director  writer  \
# 0  4692       6      6  1980      1304    8.4   927000      1795    2832
# 1  3929       6      1  1980      1127    5.8    65000      1578    1158
# 2  3641       4      0  1980      1359    8.7  1200000       757    1818
# 3   204       4      4  1980      1127    7.7   221000       889    1413
# 4   732       6      4  1980      1170    7.3   108000       719     351
#
#    star  country    budget      gross  company  runtime  released_date  \
# 0   699       46  19000000   46998772     1426    146.0            363
# 1   214       47   4500000   58853106      452    104.0            924
# 2  1157       47  18000000  538375067      945    124.0            993
# 3  1474       47   3500000   83453539     1108     88.0            924
# 4   271       47   6000000   39846344     1083     98.0           1409
#
#    country_released
# 0                47
# 1                47
# 2                47
# ...

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score    votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %%
correlation_matrix =df_numerized.corr(method= 'pearson') 

sns.heatmap(correlation_matrix, annot= True)
plt.title('Correlation Matrix')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')
# Out:
# Text(86.09375, 0.5, 'Movie Features')

# %%
correlation_matrix_numerized=df_numerized.corr()
correlation_matrix_numerized
# Out:
#                       name    rating     genre      year  released     score  \
# name              1.000000 -0.029234  0.010996  0.025542 -0.006152  0.014450
# rating           -0.029234  1.000000  0.147796  0.019499  0.018083  0.065983
# genre             0.010996  0.147796  1.000000 -0.073167  0.022142  0.035106
# year              0.025542  0.019499 -0.073167  1.000000 -0.001740  0.056386
# released         -0.006152  0.018083  0.022142 -0.001740  1.000000  0.045874
# score             0.014450  0.065983  0.035106  0.056386  0.045874  1.000000
# votes             0.012615  0.006031 -0.135990  0.206021  0.028833  0.474256
# director          0.015246  0.014656 -0.008553 -0.038354  0.002308  0.005413
# writer            0.012880 -0.003149  0.017578 -0.025908  0.008072  0.012843
# star             -0.006882  0.009196  0.003341 -0.032157  0.015706  0.007296
# country          -0.025490  0.008230 -0.009164 -0.066748 -0.017228 -0.043051
# ...

# %%
correlation_pair = correlation_matrix_numerized.unstack()
sort_pair =correlation_pair.sort_values(ascending= False)
sort_pair
# Out:
# name           name             1.000000
# rating         rating           1.000000
# released_date  released_date    1.000000
# runtime        runtime          1.000000
# company        company          1.000000
#                                   ...
# rating         budget          -0.203946
# genre          gross           -0.244101
# gross          genre           -0.244101
# genre          budget          -0.368523
# budget         genre           -0.368523
# Length: 289, dtype: float64

# %%
sort_pair[(sort_pair)>0.5]
# Out:
# name              name                1.000000
# rating            rating              1.000000
# released_date     released_date       1.000000
# runtime           runtime             1.000000
# company           company             1.000000
# gross             gross               1.000000
# budget            budget              1.000000
# country           country             1.000000
# star              star                1.000000
# director          director            1.000000
# votes             votes               1.000000
# score             score               1.000000
# released          released            1.000000
# year              year                1.000000
# genre             genre               1.000000
# writer            writer              1.000000
# country_released  country_released    1.000000
# budget            gross               0.740247
# gross             budget              0.740247
#                   votes               0.614751
# ...
